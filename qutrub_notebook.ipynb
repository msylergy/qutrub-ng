# %% [markdown]
# # Qutrub Arabic Verb Conjugation NotebookThis notebook demonstrates how to use the Qutrub Arabic verb conjugation library.Qutrub (قطرب) is an Arabic verb conjugation software that can conjugate Arabic verbs in various tenses and forms.

# %% [markdown]
# ## Installation and SetupFirst, let's install required dependencies and import the library.

# %%
# Install required packages!pip install pyarabic!pip install libqutrub

# %%
# Import necessary librariesimport libqutrub.conjugatorimport libqutrub.verb_validfrom libqutrub.ar_verb import get_future_type_entreeimport pyarabic.araby as arabyprint("Qutrub library imported successfully!")

# %% [markdown]
# ## Basic Verb ConjugationLet's start with basic verb conjugation using the `conjugate` function.The main function signature is:```pythonconjugate(verb, future_type, ...)```- `verb`: Arabic verb in vocalized form- `future_type`: For triliteral verbs, the mark of 'Ain' in the future (فتحة، ضمة، كسرة)- Additional parameters for specific tenses and forms

# %%
# Example 1: Simple conjugationverb = u"سعد"  # "to be happy"future_type = u"كسرة"  # kasra for the 'ain# Conjugate in all tensesresult = libqutrub.conjugator.conjugate(    verb,     future_type,     alltense=True,    transitive=True)print(f"Conjugation for verb '{verb}':")print(result)

# %% [markdown]
# ## Different Display FormatsQutrub supports multiple output formats. Let's explore some of them:

# %%
# Test different display formatsverb = u"كَتَبَ"  # "to write"future_type = u"ضمة"  # damma for the 'ainformats = ["TEXT", "HTML", "DICT", "CSV", "TABLE"]for fmt in formats:    print(f"\n=== Format: {fmt} ===")    try:        result = libqutrub.conjugator.conjugate(            verb,             future_type,             alltense=True,             transitive=True,            display_format=fmt        )        if fmt == "DICT":            print(f"Dictionary with {len(result)} entries")            # Show first few entries            first_items = list(result.items())[:3]            for key, value in first_items:                print(f"  {key}: {value}")            if len(result) > 3:                print(f"  ... and {len(result) - 3} more entries")        elif fmt == "TABLE":            print(result[:200] + "..." if len(result) > 200 else result)        else:            print(result[:300] + "..." if len(result) > 300 else result)    except Exception as e:        print(f"Error with format {fmt}: {e}")

# %% [markdown]
# ## Verb ValidationBefore conjugating, we should validate if the verb is a proper infinitive form.

# %%
# Test verb validationtest_verbs = [u"كَتَبَ", u"ضَرَبَ", u"سَكَتَ", u"كتب", u"invalidverb"]for verb in test_verbs:    is_valid = libqutrub.verb_valid.is_valid_infinitive_verb(verb)    print(f"Verb '{verb}': {'Valid' if is_valid else 'Invalid'}")        if is_valid:        # Get potential future types        future_types = get_future_type_entree(verb)        print(f"  Possible future types: {future_types}")

# %% [markdown]
# ## Specific Tense ConjugationLet's conjugate specific tenses instead of all tenses.

# %%
# Conjugate specific tensesverb = u"ذَهَبَ"  # "to go"future_type = u"فَتْحة"  # fatha for the 'aintenses = [    ("Past", lambda: libqutrub.conjugator.conjugate(verb, future_type, past=True, transitive=True)),    ("Future/Present", lambda: libqutrub.conjugator.conjugate(verb, future_type, future=True, transitive=True)),    ("Imperative", lambda: libqutrub.conjugator.conjugate(verb, future_type, imperative=True, transitive=True)),    ("Passive", lambda: libqutrub.conjugator.conjugate(verb, future_type, passive=True, transitive=True))]for tense_name, conj_func in tenses:    print(f"\n=== {tense_name} Tense ===")    try:        result = conj_func()        print(result[:400] + "..." if len(result) > 400 else result)    except Exception as e:        print(f"Error: {e}")

# %% [markdown]
# ## Working with Different Verb TypesLet's test various verb types, including transitive and intransitive verbs.

# %%
# Test different verb typesverbs_data = [    (u"كَتَبَ", u"ضمة", "transitive", "to write"),    (u"ضَرَبَ", u"كسرة", "transitive", "to hit"),    (u"سَكَتَ", u"ضمة", "intransitive", "to be silent"),    (u"سَكَنَ", u"ضمة", "transitive", "to make people calm"),    (u"عَلَّمَ", u", "transitive", "to teach"),    (u"أَكْرَمَ", u", "transitive", "to honor"),    (u"تَفَقَّدَ", u", "transitive", "to check"),    (u"صَارَعَ", u", "transitive", "to wrestle"),    (u"اِدَّارَكَ", u", "transitive", "to realize"),]for verb, future_type, trans_type, meaning in verbs_data:    print(f"\n=== {verb} ({meaning}) ===")        # Check if valid    is_valid = libqutrub.verb_valid.is_valid_infinitive_verb(verb)    if not is_valid:        print(f"  Invalid infinitive verb")        continue        # Set transitivity    is_transitive = trans_type == "transitive"        try:        # Conjugate with dictionary format for cleaner output        result = libqutrub.conjugator.conjugate(            verb,             future_type if future_type != "," else u"كسرة",  # Default to kasra if not specified            alltense=False,            past=True,  # Show only past tense for brevity            transitive=is_transitive,            display_format="COMPACT"  # Try compact format        )                if isinstance(result, dict):            # Show a few keys from the dictionary            items = list(result.items())[:5]            for key, value in items:                print(f"  {key}: {value}")            if len(result) > 5:                print(f"  ... and {len(result) - 5} more entries")        else:            # Limit output length for readability            print(result[:200] + "..." if len(result) > 200 else result)                except Exception as e:        print(f"  Error conjugating: {e}")

# %% [markdown]
# ## Advanced FeaturesLet's explore some advanced features like confirmed forms and mood variations.

# %%
# Advanced conjugation featuresverb = u"كَتَبَ"future_type = u"ضمة"advanced_options = [    ("Future Subjunctive (مَنْصُوب)", lambda: libqutrub.conjugator.conjugate(        verb, future_type, future=True, future_moode=True, transitive=True, display_format="TEXT")),    ("Future Jussive (مَجْزُوم)", lambda: libqutrub.conjugator.conjugate(        verb, future_type, future=True, future_moode=False, transitive=True, display_format="TEXT")),    ("Confirmed Future", lambda: libqutrub.conjugator.conjugate(        verb, future_type, future=True, confirmed=True, transitive=True, display_format="TEXT"))]for name, conj_func in advanced_options:    print(f"\n=== {name} ===")    try:        result = conj_func()        print(result[:300] + "..." if len(result) > 300 else result)    except Exception as e:        print(f"Error: {e}")

# %% [markdown]
# ## Interactive Verb TestingNow you can test your own Arabic verbs! Just modify the verb below and run the cell.

# %%
# Interactive verb testing# Modify these variables to test different verbsmy_verb = u"كَتَبَ"  # Change this to your verbmy_future_type = u"ضمة"  # Options: "فَتْحة", "ضَمّة", "كَسْرة", or "," for non-triliteralprint(f"Testing verb: {my_verb}")print(f"Future type: {my_future_type}")# Validate the verbis_valid = libqutrub.verb_valid.is_valid_infinitive_verb(my_verb)if is_valid:    print("✓ Valid infinitive verb")        # Conjugate with text format    result = libqutrub.conjugator.conjugate(        my_verb,         my_future_type,         alltense=True,        transitive=True,        display_format="TEXT"    )    print("\nFull conjugation:")    print(result)else:    print("✗ Invalid infinitive verb")    print("Please use a properly vocalized verb")

# %% [markdown]
#         stripped_word = araby.strip_harakat(word)

# %%
# 🔧 MODIFY THIS - Enter your Arabic root verb:ROOT_VERB = "كَتَبَ"  # <-- CHANGE THIS TO YOUR ROOT VERB# 🎨 Display options (optional customization)SHOW_DIACRITICS = True  # Set False to remove diacriticsMAX_TABLE_WIDTH = 100   # Characters width for tableprint(f"🔍 Analyzing verb forms for root: {ROOT_VERB}")print("=" * 60)## 📋 Generate Forms Tabletry:    # Import verb form detector for additional info    try:        from libqutrub.verb_form_detector import detect_verb_form        detector_available = True    except ImportError:        print("⚠️  Verb form detector not available, using basic conjugation...")        detector_available = False        # Generate Forms Table using new display format    print("📊 Generating Forms Table (I-X)...")    print()        forms_table = libqutrub.conjugator.conjugate(        word=ROOT_VERB,              # ✅ Use correct parameter name!        future_type="ضمة",            # Default future type        display_format="FORM_TABLE",     # 🎯 KEY: Use FORM_TABLE format!        transitive=True    )        print("📋 ARABIC VERB FORMS TABLE")    print("=" * 80)    print(forms_table)    print("=" * 80)        # Additional analysis if detector is available    if detector_available:        print("\n🔬 FORM ANALYSIS:")        try:            detected_form = detect_verb_form(ROOT_VERB)            print(f"   📌 Detected: {ROOT_VERB} is Form {detected_form.get('form_number', 'Unknown')}")            print(f"   📈 Confidence: {detected_form.get('confidence', 'Unknown')}%")            print(f"   📚 Pattern: {detected_form.get('pattern_name', 'Unknown')}")        except Exception as e:            print(f"   ⚠️  Could not detect form: {e}")        print(f"\n✅ Successfully generated all verb forms for: {ROOT_VERB}")    print("\n💡 Try different roots above to explore various verb patterns!")except Exception as e:    print(f"❌ Error generating forms table: {e}")    print("\n🔧 TROUBLESHOOTING:")    print("   • Make sure your verb is properly vocalized (with fatha, damma, or kasra)")    print("   • Use a 3-letter root verb (مُثَلَّث)")    print("   • Examples: كَتَبَ, ضَرَبَ, سَمِعَ, فَتَحَ, عَلِمَ, كَسَرَ, ذَهَبَ")    print("   • Check that libqutrub is properly installed")    print("   • Verify correct parameter names in function calls")
